# %%
from langchain_community.document_loaders import PyPDFLoader
import os
import logging

# %%
directory = "/home/ubuntu/Multi-Agent-LLM-System-with-LangGraph-RAG-and-LangChain/filtered_dataset_csv_pdfs"
pdf_contents = {}
for filename in os.listdir(directory):
    if filename.endswith(".pdf"):
        file_path = os.path.join(directory, filename)
        loader = PyPDFLoader(file_path)
        pages = loader.load()
        content = "\n".join(page.page_content for page in pages)
        pdf_contents[filename] = content
# Out:
# Ignoring wrong pointing object 61 0 (offset 0)
# Ignoring wrong pointing object 70 0 (offset 0)

# %%
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger()

directory = "/home/ubuntu/Multi-Agent-LLM-System-with-LangGraph-RAG-and-LangChain/filtered_dataset_csv_pdfs"
pdf_contents = {}

for filename in os.listdir(directory):
    if filename.endswith(".pdf"):
        file_path = os.path.join(directory, filename)
        logger.info(f"Processing file: {filename}")
        loader = PyPDFLoader(file_path)
        pages = loader.load()
        # logger.info(f"Successfully processed file: {filename}")
        content = "\n".join(page.page_content for page in pages)
        pdf_contents[filename] = content
# Out:
# INFO:root:Processing file: 10.1371_journal.pone.0076906.pdf
# INFO:root:Processing file: 10.1038_srep04576.pdf
# INFO:root:Processing file: 10.3892_or.2011.1482.pdf
# INFO:root:Processing file: 10.1038_sj.ejhg.5201002.pdf
# INFO:root:Processing file: 10.1186_1757-2215-6-82.pdf
# INFO:root:Processing file: 10.1038_sj.bjc.6603553.pdf
# INFO:root:Processing file: 10.1186_1471-2121-13-9.pdf
# INFO:root:Processing file: 10.1186_1471-2350-12-138.pdf
# INFO:root:Processing file: 10.1101_gr.134445.111.pdf
# INFO:root:Processing file: 10.3892_ijo.2013.1916.pdf
# INFO:root:Processing file: 10.1371_journal.pone.0016182.pdf
# INFO:root:Processing file: 10.1186_1471-2407-12-627.pdf
# INFO:root:Processing file: 10.3389_fphys.2014.00139.pdf
# INFO:root:Processing file: 10.1371_journal.pone.0064496.pdf
# INFO:root:Processing file: 10.1371_journal.pone.0075907.pdf
# INFO:root:Processing file: 10.3389_fncel.2013.00168.pdf
# INFO:root:Processing file: 10.3892_ol.2012.996.pdf
# ...

# %%
loader = PyPDFLoader(
    "/home/ubuntu/Multi-Agent-LLM-System-with-LangGraph-RAG-and-LangChain/filtered_dataset_csv_pdfs/10.4081_aiua.2015.2.121.pdf"
)
pages = loader.load()
print(len(pages))
content = "\n".join(page.page_content for page in pages)
print(content)
# Out:
# WARNING:pypdf._reader:Ignoring wrong pointing object 61 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 70 0 (offset 0)
# 9
# 121 Archivio Italiano di Urologia e Andrologia 2015; 87, 2ORIGINALPAPER
# Efﬁcacy and safety of second-line agents for treatment
# of metastatic castration-resistant prostate cancer
# progressing after docetaxel.
# A systematic review and meta-analysis
# Gianpaolo Perletti1,2, Elena Monti1, Emanuela Marras1, Anne Cleves3, Vittorio Magri4,
# Alberto Trinchieri5, Paul S. Rennie6
# 1 Biomedical Research Division, Dept. of Theoretical and Applied Sciences, Università degli Studi dell'Insubria, Busto Arsizio, Italy
# 2 Department of Basic Medical Sciences, Ghent University, Ghent, Belgium;
# 3 Cancer Research Wales Library, Cardiff University Velindre Hospital, Cardiff, UK;
# 4 Urology Secondary Care Clinic, Istituti Clinici di Perfezionamento, Milano, Italy;
# 5 Urology Unit, A. Manzoni Hospital, Lecco, Italy;
# ...
